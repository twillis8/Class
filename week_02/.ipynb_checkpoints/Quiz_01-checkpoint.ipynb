# %% [markdown]
# # Question 1
# ![image.png](attachment:efbefc4b-d3a4-42e9-a622-945269167ebb.png)

# %% [markdown]
# # Question 2
# I have two repos that I store in the same folder called "newcsci_1070". I did it this way because I would push my code in my repo and pull the code from the teacher's repo, so these repos will use a lot and I would them to be in the same place. In my repo, I have folders that hold the different weeks so that I can put the material that we have learned of that week in the specific folder. The material for week 1 will be under week one and the material for week 2 will be under week 2.

# %%
# Question 3
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
for month in months:
    if month == "May":
        print(month + " is my birthday!")
# Out:
# May is my birthday!
